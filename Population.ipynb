# %%
import pandas as pd

# %%
pop0010 = pd.read_csv('G:/Study/GWU/SS19/DNSC6217_Practicum/Other Source/co-est00int-alldata-51.csv')

# %%
pop1017 = pd.read_csv('G:/Study/GWU/SS19/DNSC6217_Practicum/Other Source/cc-est2017-alldata-51.csv')

# %%
pop0010.head()
# Out:
#    SUMLEV  STATE  COUNTY    STNAME          CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0      50     51       1  Virginia  Accomack County     1       0      508
# 1      50     51       1  Virginia  Accomack County     1       1     1827
# 2      50     51       1  Virginia  Accomack County     1       2     2696
# 3      50     51       1  Virginia  Accomack County     1       3     2655
# 4      50     51       1  Virginia  Accomack County     1       4     2584
#
#    TOT_MALE  TOT_FEMALE     ...       HBA_MALE  HBA_FEMALE  HIA_MALE  \
# 0       255         253     ...              1           0         0
# 1       927         900     ...              5           1         2
# 2      1409        1287     ...              4           3         2
# 3      1351        1304     ...              3           7         3
# 4      1417        1167     ...              5           8         1
#
#    HIA_FEMALE  HAA_MALE  HAA_FEMALE  HNA_MALE  HNA_FEMALE  HTOM_MALE  \
# ...

# %%
pop0010_drop = pop0010.drop(pop0010[pop0010.YEAR.isin([1,2,3,4,5,12])].index)

# %%
pop0010_drop_replace = pop0010_drop.replace({'YEAR' : { 6: '2004', 7: '2005', 8: '2006', 9: '2007', 10: '2008', 11: '2009', 13: '2010'}})

# %%
pop0010_sum = pop0010_drop_replace.loc[pop0010_drop_replace['AGEGRP'] == 99]

# %%
pop0010_sum.head()
# Out:
#      SUMLEV  STATE  COUNTY    STNAME          CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 119      50     51       1  Virginia  Accomack County  2004      99    36310
# 139      50     51       1  Virginia  Accomack County  2005      99    35835
# 159      50     51       1  Virginia  Accomack County  2006      99    35192
# 179      50     51       1  Virginia  Accomack County  2007      99    34553
# 199      50     51       1  Virginia  Accomack County  2008      99    33970
#
#      TOT_MALE  TOT_FEMALE     ...       HBA_MALE  HBA_FEMALE  HIA_MALE  \
# 119     17615       18695     ...             45          47        28
# 139     17437       18398     ...             46          44        29
# 159     17146       18046     ...             49          44        36
# 179     16821       17732     ...             48          43        36
# 199     16519       17451     ...             53          40        46
#
#      HIA_FEMALE  HAA_MALE  HAA_FEMALE  HNA_MALE  HNA_FEMALE  HTOM_MALE  \
# ...

# %%
pop1017_drop = pop1017.drop(pop1017[pop1017.YEAR.isin([1,2,3])].index)

# %%
pop1017_drop_replace = pop1017_drop.replace({'YEAR' : { 4: '2011', 5: '2012', 6: '2013', 7: '2014', 8: '2015', 9: '2016', 10: '2017'}})

# %%
pop1017_sum = pop1017_drop_replace.loc[pop1017_drop_replace['AGEGRP'] == 0]

# %%
pop1017_sum.head()
# Out:
#      SUMLEV  STATE  COUNTY    STNAME          CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 57       50     51       1  Virginia  Accomack County  2011       0    33222
# 76       50     51       1  Virginia  Accomack County  2012       0    33264
# 95       50     51       1  Virginia  Accomack County  2013       0    32963
# 114      50     51       1  Virginia  Accomack County  2014       0    32965
# 133      50     51       1  Virginia  Accomack County  2015       0    32911
#
#      TOT_MALE  TOT_FEMALE     ...       HWAC_MALE  HWAC_FEMALE  HBAC_MALE  \
# 57      16223       16999     ...            1503         1182         73
# 76      16275       16989     ...            1491         1154         81
# 95      16090       16873     ...            1443         1151         78
# 114     16067       16898     ...            1398         1151         97
# 133     16024       16887     ...            1419         1178        105
#
# ...

# %%
pop1017_sum.shape
# Out:
# (931, 80)

# %%
pop0010_sum.shape
# Out:
# (938, 50)

# %%
population_raw = pd.concat([pop0010_sum, pop1017_sum], ignore_index=True)
# Out:
# G:\Study\Python\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
population_raw.shape
# Out:
# (1869, 80)

# %%
population = population_raw[['STNAME','CTYNAME','YEAR','TOT_POP']]

# %%
population.describe(include=['object'])
# Out:
#           STNAME             CTYNAME  YEAR
# count       1869                1869  1869
# unique         1                 134    14
# top     Virginia  Mecklenburg County  2005
# freq        1869                  14   134

# %%
population.to_csv('population.csv')

# %%
population2 = population['CTYNAME']
